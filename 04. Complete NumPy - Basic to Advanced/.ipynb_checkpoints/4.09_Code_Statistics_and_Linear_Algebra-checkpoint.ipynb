# %% [markdown]
# ---

# %% [markdown]
# ## Numpy-9 : Statistics & Linear Algebra Built-In Methods in NumPy

# %%
import numpy as np
from numpy.random import randint as ri

# %%
mat1 = ri(1,10,9).reshape(3,3)
mat2 = ri(1,10,9).reshape(3,3)
print("\n1st Matrix of random single-digit numbers\n","-"*50,"\n",mat1)
print("\n2nd Matrix of random single-digit numbers\n","-"*50,"\n",mat2)
# Out:
# 1st Matrix of random single-digit numbers
#  --------------------------------------------------
#  [[5 4 4]
#  [9 5 5]
#  [2 1 7]]
#
# 2nd Matrix of random single-digit numbers
#  --------------------------------------------------
#  [[1 1 1]
#  [8 5 7]
#  [2 5 6]]

# %%
print("\nSum of all numbers in 1st matrix\n","-"*50,"\n",np.sum(mat1))
print(mat1.shape)
print("\nSum of all numbers in columns of 1st matrix\n","-"*50,"\n",np.sum(mat1,axis=0))
# Out:
# Sum of all numbers in 1st matrix
#  --------------------------------------------------
#  42
# (3, 3)
#
# Sum of all numbers in columns of 1st matrix
#  --------------------------------------------------
#  [16 10 16]

# %%
print(mat1.shape)
print("\nSum of all numbers in rows of 1st matrix\n","-"*50,"\n",np.sum(mat1,axis=1))#axis-0:row-wise
print("\nSum of all numbers in columns of 1st matrix\n","-"*50,"\n",np.sum(mat1,axis=0))#axis-1:column-wise
print("\nProduct of all numbers in rows of 1st matrix\n","-"*50,"\n",np.prod(mat1,axis=1))
# Out:
# (3, 3)
#
# Sum of all numbers in rows of 1st matrix
#  --------------------------------------------------
#  [13 19 10]
#
# Sum of all numbers in columns of 1st matrix
#  --------------------------------------------------
#  [16 10 16]
#
# Product of all numbers in rows of 1st matrix
#  --------------------------------------------------
#  [ 80 225  14]

# %%
#in 2-d array(row-no,col-no)
#     axis=0: row-changes(column is constant)
#     axis=1: column-changes(row is constant)  
# in 3-d array(array-no,row-no,col-no)
#     axis=0: block changes
#     axis=1: row changes
#     axis=2: column changes

# %%
print(mat2)
print("\nProduct of all numbers in columns of 2nd matrix\n","-"*50,"\n",np.prod(mat2,axis=0))
print("\nMean of all numbers in 1st matrix\n","-"*50,"\n",np.mean(mat1))
print(np.sum(mat2))
# Out:
# [[1 1 1]
#  [8 5 7]
#  [2 5 6]]
#
# Product of all numbers in columns of 2nd matrix
#  --------------------------------------------------
#  [16 25 42]
#
# Mean of all numbers in 1st matrix
#  --------------------------------------------------
#  4.666666666666667
# 36

# %%
print(np.reshape(mat1,(9)))
print(100*"-")
print(mat1)
print("\nStandard deviation of all numbers in 1st matrix\n","-"*50,"\n",np.std(mat1))
# Out:
# [5 4 4 9 5 5 2 1 7]
# ----------------------------------------------------------------------------------------------------
# [[5 4 4]
#  [9 5 5]
#  [2 1 7]]
#
# Standard deviation of all numbers in 1st matrix
#  --------------------------------------------------
#  2.260776661041756

# %%
print(ri(1,100,10))
mat1 = ri(1,100,9).reshape(3,3)
print(mat1)
print("\nModified matrix of random numbers from 1 to 99\n","-"*50,"\n",mat1)
# Out:
# [58 88 26 19 33 56 17 42 46 90]
# [[14 50 82]
#  [83 49 66]
#  [97  9 63]]
#
# Modified matrix of random numbers from 1 to 99
#  --------------------------------------------------
#  [[14 50 82]
#  [83 49 66]
#  [97  9 63]]

# %%
print("\nStandard deviation of all numbers in the modified matrix, a larger number\n","-"*80,"\n",np.std(mat1))
# Out:
# Standard deviation of all numbers in the modified matrix, a larger number
#  --------------------------------------------------------------------------------
#  28.448784391135824

# %%
print(23.994340896589105 ** 2)
print("\nVariance of all numbers in the modified matrix, a larger number\n","-"*80,"\n",np.var(mat1))
# Out:
# 575.7283950617284
#
# Variance of all numbers in the modified matrix, a larger number
#  --------------------------------------------------------------------------------
#  809.3333333333334

# %%
print(sorted(np.reshape(mat1,(9))))
print("\nMedian of all numbers in the modified matrix\n","-"*60,"\n",np.median(mat1))
# Out:
# [np.int32(9), np.int32(14), np.int32(49), np.int32(50), np.int32(63), np.int32(66), np.int32(82), np.int32(83), np.int32(97)]
#
# Median of all numbers in the modified matrix
#  ------------------------------------------------------------
#  63.0

# %%
mat2 = np.array(ri(1,100,50)).reshape(10,5)
mat2
# Out:
# array([[13, 76, 23, 51, 87],
#        [56, 18, 86, 69, 68],
#        [58, 57, 42,  3, 82],
#        [62, 76, 80, 87, 67],
#        [28, 34, 52, 60,  2],
#        [ 1, 81, 75, 13, 64],
#        [35, 81,  6, 13, 59],
#        [12, 20, 23, 65, 55],
#        [29, 18, 80, 17, 93],
#        [ 4, 83, 59, 89, 95]], dtype=int32)

# %%
print("\nModified matrix of 50 random numbers from 1 to 99\n","-"*50,"\n",mat2)
print(np.reshape(mat2,(50)))
# Out:
# Modified matrix of 50 random numbers from 1 to 99
#  --------------------------------------------------
#  [[13 76 23 51 87]
#  [56 18 86 69 68]
#  [58 57 42  3 82]
#  [62 76 80 87 67]
#  [28 34 52 60  2]
#  [ 1 81 75 13 64]
#  [35 81  6 13 59]
#  [12 20 23 65 55]
#  [29 18 80 17 93]
#  [ 4 83 59 89 95]]
# [13 76 23 51 87 56 18 86 69 68 58 57 42  3 82 62 76 80 87 67 28 34 52 60
#   2  1 81 75 13 64 35 81  6 13 59 12 20 23 65 55 29 18 80 17 93  4 83 59
#  89 95]

# %%
print("\nStandard deviation along the columns in the modified matrix\n","-"*60,"\n",np.std(mat2,axis=0))
print(100*"-","\n",mat2)
print(100*"-")
print(np.sort(mat2,axis=1))
print(np.median(mat2,axis=1))
# Out:
# Standard deviation along the columns in the modified matrix
#  ------------------------------------------------------------
#  [21.5490139  27.24408193 26.82610669 30.82872038 25.54916828]
# ----------------------------------------------------------------------------------------------------
#  [[13 76 23 51 87]
#  [56 18 86 69 68]
#  [58 57 42  3 82]
#  [62 76 80 87 67]
#  [28 34 52 60  2]
#  [ 1 81 75 13 64]
#  [35 81  6 13 59]
#  [12 20 23 65 55]
#  [29 18 80 17 93]
#  [ 4 83 59 89 95]]
# ----------------------------------------------------------------------------------------------------
# [[13 23 51 76 87]
#  [18 56 68 69 86]
#  [ 3 42 57 58 82]
#  [62 67 76 80 87]
#  [ 2 28 34 52 60]
#  [ 1 13 64 75 81]
#  [ 6 13 35 59 81]
#  [12 20 23 55 65]
#  [17 18 29 80 93]
#  [ 4 59 83 89 95]]
# [51. 68. 57. 76. 34. 64. 35. 23. 29. 83.]

# %%
mat1 = np.array(ri(1,100,20)).reshape(4,5)

# %%
print("\nModified matrix of random numbers from 1 to 49\n","-"*50,"\n",mat1)
# Out:
# Modified matrix of random numbers from 1 to 49
#  --------------------------------------------------
#  [[40 73 76 10 72]
#  [78 35 41  6 93]
#  [99 84 19 81 19]
#  [50 34 97 88  7]]

# %%
print("\nFlattened and sorted matrix (as vector)\n","-"*50,"\n",np.sort(mat1.reshape(1,1,20)))
# Out:
# Flattened and sorted matrix (as vector)
#  --------------------------------------------------
#  [[[ 6  7 10 19 19 34 35 40 41 50 72 73 76 78 81 84 88 93 97 99]]]

# %% [markdown]
# **Both percentiles and quantiles are statistical measures that describe the relative standing of a value within a dataset — i.e., how data is distributed.**
#
# - A percentile indicates the value below which a given percentage of data points fall.

# %%
print(np.sort(np.reshape(mat1,(20))))
print("\n50th percentile of all numbers in the modified matrix\n","-"*60,"\n",np.percentile(mat1,50))
# Out:
# [ 6  7 10 19 19 34 35 40 41 50 72 73 76 78 81 84 88 93 97 99]
#
# 50th percentile of all numbers in the modified matrix
#  ------------------------------------------------------------
#  61.0

# %%
print("\n90th percentile of all numbers in the modified matrix\n","-"*60,"\n",np.percentile(mat1,90))
# Out:
# 90th percentile of all numbers in the modified matrix
#  ------------------------------------------------------------
#  93.4

# %%
A = ri(1,5,20) # 20 random integeres from a small range (1-10)
print(A)
B = 2*A+5*np.random.randn(20) # B is twice that of A plus some random noise
print(B)
print("\nB is twice that of A plus some random noise")
# Out:
# [2 1 1 3 1 1 2 4 2 4 2 2 2 2 3 1 1 1 3 3]
# [  9.58392394  -8.28183778  10.64863953   8.82819075   2.65627992
#    1.74242426 -11.33046864  13.09144091   1.99499029   0.16401498
#   10.46031571  -0.74407923   3.76513562   7.67296248   6.92765252
#    8.18818288  -4.15555965  -4.93096024  14.15835706   7.71714126]
#
# B is twice that of A plus some random noise

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\pc\.conda\envs\decodeaienv\lib\site-packages (3.10.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\pc\.conda\envs\decodeaienv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\pc\.conda\envs\decodeaienv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\pc\.conda\envs\decodeaienv\lib\site-packages (from matplotlib) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\pc\.conda\envs\decodeaienv\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\pc\.conda\envs\decodeaienv\lib\site-packages (from matplotlib) (2.0.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\pc\.conda\envs\decodeaienv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\pc\.conda\envs\decodeaienv\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\pc\.conda\envs\decodeaienv\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\pc\.conda\envs\decodeaienv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\pc\.conda\envs\decodeaienv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.scatter(A,B) # Scatter plot of B
plt.title("Scatter plot of A vs. B, expect a small positive correlation")
plt.show()

# %%
print(np.corrcoef(A,B)) # Correleation coefficient matrix between A and B
# Out:
# [[1.         0.54246065]
#  [0.54246065 1.        ]]

# %%
A = ri(1,50,20) # 20 random integeres from a larger range (1-50)
print(A)
B = 100-2*A+10*np.random.randn(20) # B is 100 minus twice that of A plus some random noise
print(np.random.randn(20))
print(B)
print("\nB is 100 minus twice that of A plus some random noise")
# Out:
# [40  6 39 10 19 30 39 21 41  1 38 16 49 27  2 20  9 43  2 33]
# [ 0.39323884  0.94972606  1.20378235 -0.96399334  1.18637752  0.49666161
#  -1.8213131  -0.0316885   1.16386892  0.93146821  0.89522845  0.52250794
#  -0.30996913 -1.04755814  0.78920735 -1.47364053 -0.25447643  0.80939833
#   0.81996343 -1.69903105]
# [ 13.75373461  80.70240666  28.3564952   69.91880616  68.84451356
#   32.58836019  38.00815523  51.23443162   0.67943147  89.24592716
#   29.88851957  59.56689388  -2.27049224  45.29254156 104.48467153
#   50.01441453  81.52280629  15.65324413  97.8355863   32.20376234]
#
# B is 100 minus twice that of A plus some random noise

# %%
plt.scatter(A,B) # Scatter plot of B
plt.title("Scatter plot of A vs. B, expect a large negative correlation")
plt.show()

# %%
print("")
print(np.corrcoef(A,B)) # Correleation coefficient matrix between A and B
# Out:
# [[ 1.         -0.96722987]
#  [-0.96722987  1.        ]]

# %% [markdown]
# #### Linear Algebra Using NumPy

# %%
A = np.arange(1,10).reshape(3,3)
B = ri(1,10,9).reshape(3,3)
print("\n1st Matrix of 1-9 single-digit numbers (A)\n","-"*50,"\n",A)
# Out:
# 1st Matrix of 1-9 single-digit numbers (A)
#  --------------------------------------------------
#  [[1 2 3]
#  [4 5 6]
#  [7 8 9]]

# %%
print("\n2nd Matrix of random single-digit numbers (B)\n","-"*50,"\n",B)
# Out:
# 2nd Matrix of random single-digit numbers (B)
#  --------------------------------------------------
#  [[7 1 7]
#  [1 7 4]
#  [3 1 2]]

# %%
print("\nDot product of A and B (for 2D arrays it is equivalent to matrix multiplication) \n","-"*80,"\n",np.dot(A,B))
# Out:
# Dot product of A and B (for 2D arrays it is equivalent to matrix multiplication)
#  --------------------------------------------------------------------------------
#  83

# %% [markdown]
# **Dot-Product Generalizes inner product to vectors and matrix multiplication for higher dimensions.**
#
# - 1-d dot product or inner product - sum of product of element
# - 2-d dot-product is equivalent to matrix multiplication - can be done using (@) as well.

# %% [markdown]
# | Operation         | Input Types         | Output Type      | Formula / Meaning                             |
# | ----------------- | ------------------- | ---------------- | --------------------------------------------- |
# | **Inner Product** | 1D vectors          | Scalar           | Sum of elementwise products                   |
# | **Outer Product** | 1D vectors          | Matrix           | All pairwise products                         |
# | **Dot Product**   | Vectors or matrices | Scalar or matrix | Vector inner product or matrix multiplication |

# %%
A = np.arange(1,6)
B = ri(1,10,5)

# %%
print("\n1st Vector of 1-5 numbers (A)\n","-"*50,"\n",A)
# Out:
# 1st Vector of 1-5 numbers (A)
#  --------------------------------------------------
#  [1 2 3 4 5]

# %%
print("\n2nd Vector of 5 random single-digit numbers (B)\n","-"*50,"\n",B)
# Out:
# 2nd Vector of 5 random single-digit numbers (B)
#  --------------------------------------------------
#  [8 8 2 1 7]

# %%
print("\nInner product of vectors A and B \n","-"*50,"\n",np.inner(A,B), "(sum of all pairwise elements)")
# Out:
# Inner product of vectors A and B
#  --------------------------------------------------
#  83 (sum of all pairwise elements)

# %%
print("\nOuter product of vectors A and B \n","-"*50,"\n",np.outer(A,B))
# Out:
# Outer product of vectors A and B
#  --------------------------------------------------
#  [[ 8  8  2  1  7]
#  [16 16  4  2 14]
#  [24 24  6  3 21]
#  [32 32  8  4 28]
#  [40 40 10  5 35]]

# %% [markdown]
# **matrix transpose and matrix inverse**

# %%
A = ri(1,10,9).reshape(3,3)

# %%
print("\n3x3 Matrix of random single-digit numbers\n","-"*50,"\n",A)
# Out:
# 3x3 Matrix of random single-digit numbers
#  --------------------------------------------------
#  [[4 1 1]
#  [9 8 8]
#  [2 7 6]]

# %%
print("\nMatrix transpose\n","-"*50,"\n",np.transpose(A))
# Out:
# Matrix transpose
#  --------------------------------------------------
#  [[4 9 2]
#  [1 8 7]
#  [1 8 6]]

# %%
B = ri(1,10,6).reshape(3,2)

# %%
 B
# Out:
# array([[7, 9],
#        [6, 8],
#        [9, 4]], dtype=int32)

# %%
print("\n3x2 Matrix of random single-digit numbers\n","-"*50,"\n",B)
# Out:
# 3x2 Matrix of random single-digit numbers
#  --------------------------------------------------
#  [[7 9]
#  [6 8]
#  [9 4]]

# %%
print("\n2x3 Matrix transpose\n","-"*50,"\n",np.transpose(B))
# Out:
# 2x3 Matrix transpose
#  --------------------------------------------------
#  [[7 6 9]
#  [9 8 4]]

# %%
print("\nMatrix multiplication of B and B-transpose\n","-"*50,"\n",np.dot(B, np.transpose(B)))
# Out:
# Matrix multiplication of B and B-transpose
#  --------------------------------------------------
#  [[130 114  99]
#  [114 100  86]
#  [ 99  86  97]]

# %% [markdown]
# **finding trace of a matrix**

# %%
A = ri(1,10,16).reshape(4,4)

# %%
print("\n4x4 Matrix of random single-digit numbers\n","-"*50,"\n",A)
# Out:
# 4x4 Matrix of random single-digit numbers
#  --------------------------------------------------
#  [[8 2 4 5]
#  [1 2 4 2]
#  [9 6 9 6]
#  [7 5 4 5]]

# %%
print("\nMatrix trace\n","-"*50,"\n",np.trace(A))
# Out:
# Matrix trace
#  --------------------------------------------------
#  24

# %%
print("\nMatrix trace with ofset +1 (upper triangle)\n","-"*50,"\n",np.trace(A,offset=1))
# Out:
# Matrix trace with ofset +1 (upper triangle)
#  --------------------------------------------------
#  12

# %%
print("\nMatrix trace with ofset -1 (lower triangle)\n","-"*50,"\n",np.trace(A,offset=-1))
# Out:
# Matrix trace with ofset -1 (lower triangle)
#  --------------------------------------------------
#  11
