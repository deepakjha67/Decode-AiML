# %% [markdown]
# # Problem: Maximum Depth of Binary Tree

# %%
"""
Problem : Rotate Image
You are given the root of a Binary Tree, find the max depth.
maximum depth is the number of nodes along the longest path from the root to leaf
"""

# %% [markdown]
# ### Approach 1

# %%
"""
To be Implemented
"""
def find_depth(root):
    pass


# Time Complexity -
# Space Complexity -

# %%
class TreeNode:
    def __init__(self, data):
        self.left = None
        self.right = None
        self.data = data

# Driver code
root = TreeNode(1)
root.left = TreeNode(2)
root.right = TreeNode(3)
root.left.left = TreeNode(4)
root.left.right = TreeNode(5)
root.right.right = TreeNode(6)

print(find_depth(root))
# Out:
# 3
