# %% [markdown]
# # Problem: Count number of Nodes in a Binary Tree

# %%
"""
Problem : 
You are given the root of a Binary Tree. Calculate no of nodes in the binary Tree
"""
# Out:
# '\nProblem : \nYou are given the root of a Binary Tree. Calculate no of nodes in the binary Tree\n'

# %% [markdown]
# ### Approach 1

# %%
"""
To be Implemented
"""
def count_nodes(root):
    pass


# Time Complexity -
# Space Complexity -

# %%
class TreeNode:
    def __init__(self, data):
        self.left = None
        self.right = None
        self.data = data

# Driver code
root = TreeNode(1)
root.left = TreeNode(2)
root.right = TreeNode(3)
root.left.left = TreeNode(4)
root.left.right = TreeNode(5)
root.right.right = TreeNode(6)

print(count_nodes(root))
# Out:
# 6
